# %% [markdown]
# **Name:**Raja Tejeshwar
#
# **Reg.No:**21BAI1665
#
# **Email:**raja.tejeshwar2021@vitstudent.ac.in
#
# **Campus:**VIT Chennai

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1 and 2)Download and Load the DataSet

# %%
df= pd.read_csv('/content/penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.tail()
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# 3) Perform Visualizations
#
#
#
#
# Univariate Analysis

# %% [markdown]
# Distribution Plot

# %%
sns.displot(df.island)

# %%
sns.distplot(df.body_mass_g)
# Out:
# <ipython-input-98-176964dae727>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-99-24e9b5890c61>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(df.flipper_length_mm)
# Out:
# <ipython-input-100-4c42e92ff055>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.flipper_length_mm)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(df.sex)

# %% [markdown]
# Pie-Chart

# %%
df['species'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='species'>

# %%
df['island'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='island'>

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='sex'>

# %% [markdown]
# Barplot

# %%
sns.barplot(x=df.island.value_counts().index,y=df.sex.value_counts())
# Out:
# <Axes: ylabel='sex'>

# %%
sns.barplot(x=df.species.value_counts().index,y=df.sex.value_counts())
# Out:
# <Axes: ylabel='sex'>

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x=df.body_mass_g,y=df.sex)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %%
sns.scatterplot(x=df.island,y=df.body_mass_g)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %% [markdown]
# lineplot

# %%
sns.lineplot(x=df.body_mass_g,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x=df.island,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='island', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x=df.culmen_length_mm,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %% [markdown]
# Multivariate Analysis

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# Heatmap

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-113-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# 4)Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# 5) Check for Missing values and deal with them.

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace=True)
df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace=True)
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(),inplace=True)
df['sex'].fillna(df['sex'].mode()[0],inplace=True)
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace=True)

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# 6)Find the outliers and replace them outliers

# %%
sns.boxplot(df['culmen_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['body_mass_g'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['flipper_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['culmen_depth_mm'])
# Out:
# <Axes: >

# %% [markdown]
# There are no Outliers in our Dataset.

# %% [markdown]
# 7)Check the correlation of independent variables with the target

# %%
df.corr()
# Out:
# <ipython-input-124-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %% [markdown]
# 8) Check for Categorical columns and perform encoding.

# %% [markdown]
# Checking For Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.island=le.fit_transform(df.island)
df.sex=le.fit_transform(df.sex)
df.species=le.fit_transform(df.species)
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3       4050.0    2
# 4       3450.0    1

# %% [markdown]
# correlation between target column and other coulmns after encoding the target column into numerical column.

# %%
print(df.corr()['species'][:])
# Out:
# species              1.000000
# island              -0.635659
# culmen_length_mm     0.728706
# culmen_depth_mm     -0.741282
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# sex                 -0.003823
# Name: species, dtype: float64

# %% [markdown]
# 9)Split the data into dependent and independent variables.

# %%
x = df.drop(columns = ['species'])
y = df.species
x.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %% [markdown]
# 10)Scaling the Data

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()
x_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
x_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.5
# 2  0.5
# 3  1.0
# 4  0.5

# %% [markdown]
# 11)Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=0)
x_train
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 219     0.5          0.658182         0.666667           0.440678
# 271     0.0          0.596364         0.119048           0.813559
# 266     0.0          0.487273         0.095238           0.644068
# 335     0.0          0.836364         0.345238           0.983051
# 217     0.5          0.636364         0.607143           0.355932
# ..      ...               ...              ...                ...
# 323     0.0          0.618182         0.226190           0.949153
# 192     0.5          0.614545         0.761905           0.644068
# 117     1.0          0.189091         0.880952           0.457627
# 47      0.5          0.196364         0.690476           0.118644
# 172     0.5          0.374545         0.500000           0.152542
#
#      body_mass_g  sex
# 219     0.298611  0.5
# 271     0.722222  1.0
# 266     0.416667  0.5
# 335     0.875000  1.0
# 217     0.298611  1.0
# ..           ...  ...
# ...

# %%
y_train
# Out:
# 219    1
# 271    2
# 266    2
# 335    2
# 217    1
#       ..
# 323    2
# 192    1
# 117    0
# 47     0
# 172    1
# Name: species, Length: 240, dtype: int64

# %%
x_test
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 141     0.5          0.309091         0.488095           0.254237
# 6       1.0          0.247273         0.559524           0.152542
# 60      0.0          0.130909         0.452381           0.220339
# 249     0.0          0.650909         0.261905           0.813559
# 54      0.0          0.087273         0.595238           0.254237
# ..      ...               ...              ...                ...
# 81      1.0          0.392727         0.535714           0.406780
# 1       1.0          0.269091         0.511905           0.237288
# 120     1.0          0.149091         0.488095           0.254237
# 8       1.0          0.072727         0.595238           0.355932
# 313     0.0          0.632727         0.357143           0.881356
#
#      body_mass_g  sex
# 141     0.215278  1.0
# 6       0.256944  0.5
# 60      0.125000  0.5
# 249     0.791667  1.0
# 54      0.055556  0.5
# ..           ...  ...
# ...

# %%
y_test
# Out:
# 141    0
# 6      0
# 60     0
# 249    2
# 54     0
#       ..
# 81     0
# 1      0
# 120    0
# 8      0
# 313    2
# Name: species, Length: 104, dtype: int64

# %% [markdown]
# 12)check the training and testing data shape

# %%
x_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
x_test.shape
# Out:
# (104, 6)

# %%
y_test.shape
# Out:
# (104,)
